# %% [markdown]
# ### Task 1 - Index creation
#
# >Set up a vector storage system. It can be any vector DBMS you want, or a SQL DBMS with vector support (for example, PostgreSQL with the pgvector add-on)

# %% [markdown]
# PostreSQL with the pgvector add-on was selected as a vector storage system. To initialize it via Docker, execute the `docker-compose up -d` command in the terminal within the directory containing the docker-compose.yml file.

# %% [markdown]
# >Set up an index management API. The API must contain the following endpoints:
# >- `/add_document` - accepts a document, splits it into chunks,vectorizes the chunks, and adds them to the vector storage;
# >- `/query` - accepts a query vector and returns the top Kclosest chunks.

# %% [markdown]
# `api_task1.py` is a simple FastAPI application implementing the required endpoints. To start the server, execute the following command in the terminal: `uvicorn api_task1:app --port 8000 --reload`

# %% [markdown]
# >Gather any document library you want. For example: scientific papers, lab reports from previous courses, etc. Populate the vector storage with the gathered documents.

# %%
import os
import requests
from pypdf import PdfReader

folder_path = "library"
api_url = "http://127.0.0.1:8000/add_document"

for filename in os.listdir(folder_path):
    if filename.endswith(".pdf"):
        file_path = os.path.join(folder_path, filename)
        
        # Read the PDF text
        reader = PdfReader(file_path)
        extracted_text = ""
        for page in reader.pages:
            extracted_text += page.extract_text() + " "
            
        if extracted_text.strip():
            # Send it to your Task 1 API
            requests.post(api_url, json={"text": extracted_text})
            print(f"Successfully processed and embedded: {filename}")
        else:
            print(f"Skipped empty or unreadable file: {filename}")
# Out:
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 58 0 (offset 0)
# Ignoring wrong pointing object 95 0 (offset 0)
# Ignoring wrong pointing object 151 0 (offset 0)
# Ignoring wrong pointing object 195 0 (offset 0)
# Ignoring wrong pointing object 222 0 (offset 0)
# Ignoring wrong pointing object 224 0 (offset 0)
# Ignoring wrong pointing object 226 0 (offset 0)
# Ignoring wrong pointing object 229 0 (offset 0)
# Ignoring wrong pointing object 231 0 (offset 0)
# Ignoring wrong pointing object 233 0 (offset 0)
# Ignoring wrong pointing object 235 0 (offset 0)
# Ignoring wrong pointing object 237 0 (offset 0)
# Ignoring wrong pointing object 268 0 (offset 0)
# Ignoring wrong pointing object 271 0 (offset 0)
# Ignoring wrong pointing object 273 0 (offset 0)
# Ignoring wrong pointing object 275 0 (offset 0)
# Ignoring wrong pointing object 277 0 (offset 0)
# Ignoring wrong pointing object 279 0 (offset 0)
# Ignoring wrong pointing object 282 0 (offset 0)
# Ignoring wrong pointing object 285 0 (offset 0)
# Ignoring wrong pointing object 287 0 (offset 0)
# Ignoring wrong pointing object 289 0 (offset 0)
# Ignoring wrong pointing object 292 0 (offset 0)
# Ignoring wrong pointing object 294 0 (offset 0)
# Ignoring wrong pointing object 297 0 (offset 0)
# Ignoring wrong pointing object 299 0 (offset 0)
# Ignoring wrong pointing object 301 0 (offset 0)
# Ignoring wrong pointing object 304 0 (offset 0)
# Ignoring wrong pointing object 363 0 (offset 0)
# Ignoring wrong pointing object 366 0 (offset 0)
# Ignoring wrong pointing object 368 0 (offset 0)
# Ignoring wrong pointing object 371 0 (offset 0)
# Ignoring wrong pointing object 373 0 (offset 0)
# Ignoring wrong pointing object 375 0 (offset 0)
# Ignoring wrong pointing object 377 0 (offset 0)
# Ignoring wrong pointing object 380 0 (offset 0)
# Ignoring wrong pointing object 382 0 (offset 0)
# Ignoring wrong pointing object 384 0 (offset 0)
# Ignoring wrong pointing object 386 0 (offset 0)
# Ignoring wrong pointing object 388 0 (offset 0)
# Ignoring wrong pointing object 391 0 (offset 0)
# Ignoring wrong pointing object 394 0 (offset 0)
# Ignoring wrong pointing object 396 0 (offset 0)
# Ignoring wrong pointing object 398 0 (offset 0)
# Ignoring wrong pointing object 401 0 (offset 0)
# Ignoring wrong pointing object 403 0 (offset 0)
# Ignoring wrong pointing object 405 0 (offset 0)
# Ignoring wrong pointing object 408 0 (offset 0)
# Ignoring wrong pointing object 410 0 (offset 0)
# Ignoring wrong pointing object 480 0 (offset 0)
# Ignoring wrong pointing object 482 0 (offset 0)
# Ignoring wrong pointing object 485 0 (offset 0)
# Ignoring wrong pointing object 487 0 (offset 0)
# Ignoring wrong pointing object 490 0 (offset 0)
# Ignoring wrong pointing object 492 0 (offset 0)
# Ignoring wrong pointing object 494 0 (offset 0)
# Ignoring wrong pointing object 497 0 (offset 0)
# Ignoring wrong pointing object 499 0 (offset 0)
# Ignoring wrong pointing object 502 0 (offset 0)
# Ignoring wrong pointing object 504 0 (offset 0)
# Ignoring wrong pointing object 506 0 (offset 0)
# Ignoring wrong pointing object 509 0 (offset 0)
# Ignoring wrong pointing object 511 0 (offset 0)
# Ignoring wrong pointing object 513 0 (offset 0)
# Ignoring wrong pointing object 515 0 (offset 0)
# Ignoring wrong pointing object 518 0 (offset 0)
# Ignoring wrong pointing object 521 0 (offset 0)
# Ignoring wrong pointing object 523 0 (offset 0)
# Ignoring wrong pointing object 525 0 (offset 0)
# Ignoring wrong pointing object 527 0 (offset 0)
# Ignoring wrong pointing object 529 0 (offset 0)
# Ignoring wrong pointing object 620 0 (offset 0)
# Ignoring wrong pointing object 623 0 (offset 0)
# Ignoring wrong pointing object 625 0 (offset 0)
# Ignoring wrong pointing object 628 0 (offset 0)
# Ignoring wrong pointing object 630 0 (offset 0)
# Ignoring wrong pointing object 632 0 (offset 0)
# Ignoring wrong pointing object 634 0 (offset 0)
# Ignoring wrong pointing object 636 0 (offset 0)
# Ignoring wrong pointing object 639 0 (offset 0)
# Ignoring wrong pointing object 642 0 (offset 0)
# Ignoring wrong pointing object 644 0 (offset 0)
# Ignoring wrong pointing object 646 0 (offset 0)
# Ignoring wrong pointing object 648 0 (offset 0)
# Ignoring wrong pointing object 651 0 (offset 0)
# Ignoring wrong pointing object 653 0 (offset 0)
# Ignoring wrong pointing object 656 0 (offset 0)
# Ignoring wrong pointing object 658 0 (offset 0)
# Ignoring wrong pointing object 660 0 (offset 0)
# Ignoring wrong pointing object 662 0 (offset 0)
# Ignoring wrong pointing object 665 0 (offset 0)
# Ignoring wrong pointing object 668 0 (offset 0)
# Ignoring wrong pointing object 670 0 (offset 0)
# Ignoring wrong pointing object 676 0 (offset 0)
# Ignoring wrong pointing object 678 0 (offset 0)
# Ignoring wrong pointing object 681 0 (offset 0)
# Ignoring wrong pointing object 723 0 (offset 0)
# Successfully processed and embedded: Лекції_МС.pdf
# Ignoring wrong pointing object 725 0 (offset 0)
# Ignoring wrong pointing object 728 0 (offset 0)
# Ignoring wrong pointing object 730 0 (offset 0)
# Ignoring wrong pointing object 733 0 (offset 0)
# Ignoring wrong pointing object 735 0 (offset 0)
# Ignoring wrong pointing object 737 0 (offset 0)
# Ignoring wrong pointing object 739 0 (offset 0)
# Ignoring wrong pointing object 748 0 (offset 0)
# Ignoring wrong pointing object 831 0 (offset 0)
# Ignoring wrong pointing object 833 0 (offset 0)
# Ignoring wrong pointing object 837 0 (offset 0)
# Ignoring wrong pointing object 839 0 (offset 0)
# Ignoring wrong pointing object 842 0 (offset 0)
# Ignoring wrong pointing object 844 0 (offset 0)
# Ignoring wrong pointing object 846 0 (offset 0)
# Ignoring wrong pointing object 849 0 (offset 0)
# Ignoring wrong pointing object 851 0 (offset 0)
# Ignoring wrong pointing object 853 0 (offset 0)
# Ignoring wrong pointing object 911 0 (offset 0)
# Ignoring wrong pointing object 913 0 (offset 0)
# Ignoring wrong pointing object 915 0 (offset 0)
# Ignoring wrong pointing object 919 0 (offset 0)
# Ignoring wrong pointing object 921 0 (offset 0)
# Ignoring wrong pointing object 923 0 (offset 0)
# Ignoring wrong pointing object 925 0 (offset 0)
# Ignoring wrong pointing object 927 0 (offset 0)
# Ignoring wrong pointing object 929 0 (offset 0)
# Ignoring wrong pointing object 932 0 (offset 0)
# Ignoring wrong pointing object 934 0 (offset 0)
# Ignoring wrong pointing object 937 0 (offset 0)
# Ignoring wrong pointing object 939 0 (offset 0)
# Ignoring wrong pointing object 941 0 (offset 0)
# Ignoring wrong pointing object 944 0 (offset 0)
# Ignoring wrong pointing object 946 0 (offset 0)
# Ignoring wrong pointing object 952 0 (offset 0)
# Ignoring wrong pointing object 955 0 (offset 0)
# Ignoring wrong pointing object 957 0 (offset 0)
# Ignoring wrong pointing object 959 0 (offset 0)
# Ignoring wrong pointing object 962 0 (offset 0)
# Ignoring wrong pointing object 964 0 (offset 0)
# Ignoring wrong pointing object 966 0 (offset 0)
# Ignoring wrong pointing object 968 0 (offset 0)
# Ignoring wrong pointing object 971 0 (offset 0)
# Ignoring wrong pointing object 973 0 (offset 0)
# Ignoring wrong pointing object 975 0 (offset 0)
# Ignoring wrong pointing object 978 0 (offset 0)
# Ignoring wrong pointing object 980 0 (offset 0)
# Ignoring wrong pointing object 982 0 (offset 0)
# Ignoring wrong pointing object 985 0 (offset 0)
# Ignoring wrong pointing object 987 0 (offset 0)
# Ignoring wrong pointing object 989 0 (offset 0)
# Ignoring wrong pointing object 991 0 (offset 0)
# Ignoring wrong pointing object 994 0 (offset 0)
# Ignoring wrong pointing object 996 0 (offset 0)
# Ignoring wrong pointing object 998 0 (offset 0)
# Ignoring wrong pointing object 1001 0 (offset 0)
# Ignoring wrong pointing object 1008 0 (offset 0)
# Ignoring wrong pointing object 1010 0 (offset 0)
# Ignoring wrong pointing object 1012 0 (offset 0)
# Ignoring wrong pointing object 1014 0 (offset 0)
# Ignoring wrong pointing object 1017 0 (offset 0)
# Ignoring wrong pointing object 1019 0 (offset 0)
# Ignoring wrong pointing object 1022 0 (offset 0)
# Ignoring wrong pointing object 1024 0 (offset 0)
# Ignoring wrong pointing object 1026 0 (offset 0)
# Ignoring wrong pointing object 1028 0 (offset 0)
# Ignoring wrong pointing object 1031 0 (offset 0)
# Ignoring wrong pointing object 1033 0 (offset 0)
# Ignoring wrong pointing object 1036 0 (offset 0)
# Ignoring wrong pointing object 1038 0 (offset 0)
# Ignoring wrong pointing object 1040 0 (offset 0)
# Ignoring wrong pointing object 1042 0 (offset 0)
# Ignoring wrong pointing object 1044 0 (offset 0)
# Ignoring wrong pointing object 1046 0 (offset 0)
# Ignoring wrong pointing object 1054 0 (offset 0)
# Ignoring wrong pointing object 1056 0 (offset 0)
# Ignoring wrong pointing object 1058 0 (offset 0)
# Ignoring wrong pointing object 1060 0 (offset 0)
# Ignoring wrong pointing object 1062 0 (offset 0)
# Ignoring wrong pointing object 1065 0 (offset 0)
# Ignoring wrong pointing object 1067 0 (offset 0)
# Ignoring wrong pointing object 1069 0 (offset 0)
# Ignoring wrong pointing object 1071 0 (offset 0)
# Ignoring wrong pointing object 1074 0 (offset 0)
# Ignoring wrong pointing object 1076 0 (offset 0)
# Ignoring wrong pointing object 1078 0 (offset 0)
# Ignoring wrong pointing object 1109 0 (offset 0)
# Ignoring wrong pointing object 1111 0 (offset 0)
# Ignoring wrong pointing object 1114 0 (offset 0)
# Ignoring wrong pointing object 1116 0 (offset 0)
# Ignoring wrong pointing object 1118 0 (offset 0)
# Ignoring wrong pointing object 1121 0 (offset 0)
# Ignoring wrong pointing object 1123 0 (offset 0)
# Ignoring wrong pointing object 1188 0 (offset 0)
# Ignoring wrong pointing object 1190 0 (offset 0)
# Ignoring wrong pointing object 1193 0 (offset 0)
# Ignoring wrong pointing object 1195 0 (offset 0)
# Ignoring wrong pointing object 1197 0 (offset 0)
# Ignoring wrong pointing object 1263 0 (offset 0)
# Ignoring wrong pointing object 1265 0 (offset 0)
# Ignoring wrong pointing object 1267 0 (offset 0)
# Ignoring wrong pointing object 1270 0 (offset 0)
# Ignoring wrong pointing object 1272 0 (offset 0)
# Ignoring wrong pointing object 1274 0 (offset 0)
# Ignoring wrong pointing object 1278 0 (offset 0)
# Ignoring wrong pointing object 1280 0 (offset 0)
# Ignoring wrong pointing object 1282 0 (offset 0)
# Ignoring wrong pointing object 1285 0 (offset 0)
# Ignoring wrong pointing object 1287 0 (offset 0)
# Ignoring wrong pointing object 1289 0 (offset 0)
# Ignoring wrong pointing object 1379 0 (offset 0)
# Ignoring wrong pointing object 1382 0 (offset 0)
# Ignoring wrong pointing object 1384 0 (offset 0)
# Ignoring wrong pointing object 1386 0 (offset 0)
# Ignoring wrong pointing object 1389 0 (offset 0)
# Ignoring wrong pointing object 1391 0 (offset 0)
# Ignoring wrong pointing object 1393 0 (offset 0)
# Ignoring wrong pointing object 1396 0 (offset 0)
# Ignoring wrong pointing object 1398 0 (offset 0)
# Ignoring wrong pointing object 1400 0 (offset 0)
# Ignoring wrong pointing object 1403 0 (offset 0)
# Ignoring wrong pointing object 1405 0 (offset 0)
# Ignoring wrong pointing object 1415 0 (offset 0)
# Ignoring wrong pointing object 1418 0 (offset 0)
# Ignoring wrong pointing object 1420 0 (offset 0)
# Ignoring wrong pointing object 1422 0 (offset 0)
# Ignoring wrong pointing object 1425 0 (offset 0)
# Ignoring wrong pointing object 1427 0 (offset 0)
# Ignoring wrong pointing object 1430 0 (offset 0)
# Ignoring wrong pointing object 1432 0 (offset 0)
# Ignoring wrong pointing object 1434 0 (offset 0)
# Ignoring wrong pointing object 1440 0 (offset 0)
# Ignoring wrong pointing object 1443 0 (offset 0)
# Ignoring wrong pointing object 1445 0 (offset 0)
# Ignoring wrong pointing object 1447 0 (offset 0)
# Ignoring wrong pointing object 1450 0 (offset 0)
# Ignoring wrong pointing object 1452 0 (offset 0)
# Ignoring wrong pointing object 1454 0 (offset 0)
# Ignoring wrong pointing object 1457 0 (offset 0)
# Ignoring wrong pointing object 1459 0 (offset 0)
# Ignoring wrong pointing object 1461 0 (offset 0)
# Ignoring wrong pointing object 1464 0 (offset 0)
# Ignoring wrong pointing object 1466 0 (offset 0)
# Ignoring wrong pointing object 1468 0 (offset 0)
# Ignoring wrong pointing object 1471 0 (offset 0)
# Ignoring wrong pointing object 1473 0 (offset 0)
# Ignoring wrong pointing object 1476 0 (offset 0)
# Ignoring wrong pointing object 1478 0 (offset 0)
# Ignoring wrong pointing object 1480 0 (offset 0)
# Ignoring wrong pointing object 1483 0 (offset 0)
# Ignoring wrong pointing object 1485 0 (offset 0)
# Ignoring wrong pointing object 1487 0 (offset 0)
# Ignoring wrong pointing object 1490 0 (offset 0)
# Ignoring wrong pointing object 1492 0 (offset 0)
# Ignoring wrong pointing object 1494 0 (offset 0)
# Ignoring wrong pointing object 1497 0 (offset 0)
# Ignoring wrong pointing object 1499 0 (offset 0)
# Ignoring wrong pointing object 1501 0 (offset 0)
# Ignoring wrong pointing object 1503 0 (offset 0)
# Ignoring wrong pointing object 1505 0 (offset 0)
# Ignoring wrong pointing object 1508 0 (offset 0)
# Ignoring wrong pointing object 1510 0 (offset 0)
# Ignoring wrong pointing object 1512 0 (offset 0)
# Ignoring wrong pointing object 1515 0 (offset 0)
# Ignoring wrong pointing object 1517 0 (offset 0)
# Ignoring wrong pointing object 1519 0 (offset 0)
# Ignoring wrong pointing object 1522 0 (offset 0)
# Ignoring wrong pointing object 1524 0 (offset 0)
# Ignoring wrong pointing object 1530 0 (offset 0)
# Ignoring wrong pointing object 1533 0 (offset 0)
# Ignoring wrong pointing object 1535 0 (offset 0)
# Ignoring wrong pointing object 1537 0 (offset 0)
# Ignoring wrong pointing object 1540 0 (offset 0)
# Ignoring wrong pointing object 1542 0 (offset 0)
# Ignoring wrong pointing object 1550 0 (offset 0)
# Ignoring wrong pointing object 1552 0 (offset 0)
# Ignoring wrong pointing object 1554 0 (offset 0)
# Ignoring wrong pointing object 1556 0 (offset 0)
# Ignoring wrong pointing object 1559 0 (offset 0)
# Ignoring wrong pointing object 1561 0 (offset 0)
# Ignoring wrong pointing object 1563 0 (offset 0)
# Ignoring wrong pointing object 1566 0 (offset 0)
# Ignoring wrong pointing object 1568 0 (offset 0)
# Ignoring wrong pointing object 1570 0 (offset 0)
# Ignoring wrong pointing object 1573 0 (offset 0)
# Ignoring wrong pointing object 1575 0 (offset 0)
# Ignoring wrong pointing object 1577 0 (offset 0)
# Ignoring wrong pointing object 1580 0 (offset 0)
# Ignoring wrong pointing object 1582 0 (offset 0)
# Ignoring wrong pointing object 1584 0 (offset 0)
# Ignoring wrong pointing object 1587 0 (offset 0)
# Ignoring wrong pointing object 1589 0 (offset 0)
# Ignoring wrong pointing object 1591 0 (offset 0)
# Ignoring wrong pointing object 1594 0 (offset 0)
# Ignoring wrong pointing object 1596 0 (offset 0)
# Ignoring wrong pointing object 1599 0 (offset 0)
# Ignoring wrong pointing object 1601 0 (offset 0)
# Ignoring wrong pointing object 1603 0 (offset 0)
# Ignoring wrong pointing object 1606 0 (offset 0)
# Ignoring wrong pointing object 1608 0 (offset 0)
# Ignoring wrong pointing object 1610 0 (offset 0)
# Ignoring wrong pointing object 1613 0 (offset 0)
# Ignoring wrong pointing object 1615 0 (offset 0)
# Ignoring wrong pointing object 1617 0 (offset 0)
# Ignoring wrong pointing object 1620 0 (offset 0)
# Ignoring wrong pointing object 1622 0 (offset 0)
# Ignoring wrong pointing object 1628 0 (offset 0)
# Ignoring wrong pointing object 1631 0 (offset 0)
# Ignoring wrong pointing object 1633 0 (offset 0)
# Ignoring wrong pointing object 1635 0 (offset 0)
# Ignoring wrong pointing object 1637 0 (offset 0)
# Ignoring wrong pointing object 1640 0 (offset 0)
# Ignoring wrong pointing object 1642 0 (offset 0)
# Ignoring wrong pointing object 1645 0 (offset 0)
# Ignoring wrong pointing object 1647 0 (offset 0)
# Ignoring wrong pointing object 1650 0 (offset 0)
# Ignoring wrong pointing object 1652 0 (offset 0)
# Ignoring wrong pointing object 1658 0 (offset 0)
# Ignoring wrong pointing object 1661 0 (offset 0)
# Ignoring wrong pointing object 1663 0 (offset 0)
# Ignoring wrong pointing object 1665 0 (offset 0)
# Ignoring wrong pointing object 1668 0 (offset 0)
# Ignoring wrong pointing object 1670 0 (offset 0)
# Ignoring wrong pointing object 1672 0 (offset 0)
# Ignoring wrong pointing object 1679 0 (offset 0)
# Ignoring wrong pointing object 1681 0 (offset 0)
# Ignoring wrong pointing object 2444 0 (offset 0)
# Ignoring wrong pointing object 2446 0 (offset 0)
# Ignoring wrong pointing object 2448 0 (offset 0)
# Ignoring wrong pointing object 2642 0 (offset 0)
# Ignoring wrong pointing object 2700 0 (offset 0)
# Ignoring wrong pointing object 2762 0 (offset 0)
# Ignoring wrong pointing object 2764 0 (offset 0)
# Ignoring wrong pointing object 2766 0 (offset 0)
# Ignoring wrong pointing object 2768 0 (offset 0)
# Ignoring wrong pointing object 2770 0 (offset 0)
# Ignoring wrong pointing object 2772 0 (offset 0)
# Ignoring wrong pointing object 2774 0 (offset 0)
# Ignoring wrong pointing object 2776 0 (offset 0)
# Ignoring wrong pointing object 2778 0 (offset 0)
# Ignoring wrong pointing object 2781 0 (offset 0)
# Ignoring wrong pointing object 2783 0 (offset 0)
# Ignoring wrong pointing object 2785 0 (offset 0)
# Ignoring wrong pointing object 2787 0 (offset 0)
# Ignoring wrong pointing object 2794 0 (offset 0)
# Ignoring wrong pointing object 2796 0 (offset 0)
# Ignoring wrong pointing object 2798 0 (offset 0)
# Ignoring wrong pointing object 2801 0 (offset 0)
# Ignoring wrong pointing object 2985 0 (offset 0)
# Ignoring wrong pointing object 2987 0 (offset 0)
# Ignoring wrong pointing object 2989 0 (offset 0)
# Ignoring wrong pointing object 3103 0 (offset 0)
# Ignoring wrong pointing object 3106 0 (offset 0)
# Ignoring wrong pointing object 3108 0 (offset 0)
# Ignoring wrong pointing object 3110 0 (offset 0)
# Ignoring wrong pointing object 3116 0 (offset 0)
# Ignoring wrong pointing object 3119 0 (offset 0)
# Ignoring wrong pointing object 3121 0 (offset 0)
# Ignoring wrong pointing object 3123 0 (offset 0)
# Ignoring wrong pointing object 3315 0 (offset 0)
# Ignoring wrong pointing object 3317 0 (offset 0)
# Ignoring wrong pointing object 3380 0 (offset 0)
# Ignoring wrong pointing object 3382 0 (offset 0)
# Ignoring wrong pointing object 3384 0 (offset 0)
# Ignoring wrong pointing object 3386 0 (offset 0)
# Ignoring wrong pointing object 3393 0 (offset 0)
# Ignoring wrong pointing object 3396 0 (offset 0)
# Ignoring wrong pointing object 3398 0 (offset 0)
# Ignoring wrong pointing object 3400 0 (offset 0)
# Ignoring wrong pointing object 3402 0 (offset 0)
# Ignoring wrong pointing object 3405 0 (offset 0)
# Ignoring wrong pointing object 3407 0 (offset 0)
# Ignoring wrong pointing object 3457 0 (offset 0)
# Ignoring wrong pointing object 3459 0 (offset 0)
# Ignoring wrong pointing object 3461 0 (offset 0)
# Ignoring wrong pointing object 3464 0 (offset 0)
# Ignoring wrong pointing object 3603 0 (offset 0)
# Ignoring wrong pointing object 3606 0 (offset 0)
# Ignoring wrong pointing object 3608 0 (offset 0)
# Ignoring wrong pointing object 3610 0 (offset 0)
# Ignoring wrong pointing object 3612 0 (offset 0)
# Ignoring wrong pointing object 3615 0 (offset 0)
# Ignoring wrong pointing object 3617 0 (offset 0)
# Ignoring wrong pointing object 3623 0 (offset 0)
# Ignoring wrong pointing object 3625 0 (offset 0)
# Ignoring wrong pointing object 3869 0 (offset 0)
# Ignoring wrong pointing object 3871 0 (offset 0)
# Ignoring wrong pointing object 3874 0 (offset 0)
# Ignoring wrong pointing object 3876 0 (offset 0)
# Ignoring wrong pointing object 3879 0 (offset 0)
# Ignoring wrong pointing object 3881 0 (offset 0)
# Ignoring wrong pointing object 3883 0 (offset 0)
# Ignoring wrong pointing object 3885 0 (offset 0)
# Ignoring wrong pointing object 3888 0 (offset 0)
# Ignoring wrong pointing object 3890 0 (offset 0)
# Ignoring wrong pointing object 3893 0 (offset 0)
# Ignoring wrong pointing object 3895 0 (offset 0)
# Ignoring wrong pointing object 3897 0 (offset 0)
# Ignoring wrong pointing object 3899 0 (offset 0)
# Ignoring wrong pointing object 3902 0 (offset 0)
# Ignoring wrong pointing object 3904 0 (offset 0)
# Ignoring wrong pointing object 3907 0 (offset 0)
# Ignoring wrong pointing object 3909 0 (offset 0)
# Ignoring wrong pointing object 3911 0 (offset 0)
# Ignoring wrong pointing object 3913 0 (offset 0)
# Ignoring wrong pointing object 3916 0 (offset 0)
# Ignoring wrong pointing object 3918 0 (offset 0)
# Ignoring wrong pointing object 3920 0 (offset 0)
# Ignoring wrong pointing object 3926 0 (offset 0)
# Ignoring wrong pointing object 3928 0 (offset 0)
# Ignoring wrong pointing object 3931 0 (offset 0)
# Ignoring wrong pointing object 3933 0 (offset 0)
# Ignoring wrong pointing object 3936 0 (offset 0)
# Ignoring wrong pointing object 3938 0 (offset 0)
# Ignoring wrong pointing object 3940 0 (offset 0)
# Ignoring wrong pointing object 3943 0 (offset 0)
# Ignoring wrong pointing object 3945 0 (offset 0)
# Ignoring wrong pointing object 3947 0 (offset 0)
# Ignoring wrong pointing object 3949 0 (offset 0)
# Ignoring wrong pointing object 3951 0 (offset 0)
# Ignoring wrong pointing object 3954 0 (offset 0)
# Ignoring wrong pointing object 3956 0 (offset 0)
# Ignoring wrong pointing object 3958 0 (offset 0)
# Ignoring wrong pointing object 3961 0 (offset 0)
# Ignoring wrong pointing object 3964 0 (offset 0)
# Ignoring wrong pointing object 3966 0 (offset 0)
# Ignoring wrong pointing object 3968 0 (offset 0)
# Ignoring wrong pointing object 3974 0 (offset 0)
# Ignoring wrong pointing object 3977 0 (offset 0)
# Ignoring wrong pointing object 3979 0 (offset 0)
# Ignoring wrong pointing object 3981 0 (offset 0)
# Ignoring wrong pointing object 3984 0 (offset 0)
# Ignoring wrong pointing object 3986 0 (offset 0)
# Ignoring wrong pointing object 3989 0 (offset 0)
# Ignoring wrong pointing object 3991 0 (offset 0)
# Ignoring wrong pointing object 3993 0 (offset 0)
# Ignoring wrong pointing object 3996 0 (offset 0)
# Ignoring wrong pointing object 3998 0 (offset 0)
# Ignoring wrong pointing object 4001 0 (offset 0)
# Ignoring wrong pointing object 4003 0 (offset 0)
# Ignoring wrong pointing object 4013 0 (offset 0)
# Ignoring wrong pointing object 4015 0 (offset 0)
# Ignoring wrong pointing object 4018 0 (offset 0)
# Ignoring wrong pointing object 4020 0 (offset 0)
# Ignoring wrong pointing object 4023 0 (offset 0)
# Ignoring wrong pointing object 4025 0 (offset 0)
# Ignoring wrong pointing object 4027 0 (offset 0)
# Ignoring wrong pointing object 4030 0 (offset 0)
# Ignoring wrong pointing object 4032 0 (offset 0)
# Ignoring wrong pointing object 4034 0 (offset 0)
# Ignoring wrong pointing object 4040 0 (offset 0)
# Ignoring wrong pointing object 4043 0 (offset 0)
# Ignoring wrong pointing object 4045 0 (offset 0)
# Ignoring wrong pointing object 4047 0 (offset 0)
# Ignoring wrong pointing object 4049 0 (offset 0)
# Ignoring wrong pointing object 4052 0 (offset 0)
# Ignoring wrong pointing object 4054 0 (offset 0)
# Ignoring wrong pointing object 4056 0 (offset 0)
# Ignoring wrong pointing object 4059 0 (offset 0)
# Ignoring wrong pointing object 4061 0 (offset 0)
# Ignoring wrong pointing object 4063 0 (offset 0)
# Ignoring wrong pointing object 4066 0 (offset 0)
# Ignoring wrong pointing object 4068 0 (offset 0)
# Ignoring wrong pointing object 4070 0 (offset 0)
# Ignoring wrong pointing object 4072 0 (offset 0)
# Ignoring wrong pointing object 4074 0 (offset 0)
# Ignoring wrong pointing object 4077 0 (offset 0)
# Ignoring wrong pointing object 4079 0 (offset 0)
# Ignoring wrong pointing object 4081 0 (offset 0)
# Ignoring wrong pointing object 4084 0 (offset 0)
# Ignoring wrong pointing object 4090 0 (offset 0)
# Ignoring wrong pointing object 4092 0 (offset 0)
# Ignoring wrong pointing object 4095 0 (offset 0)
# Ignoring wrong pointing object 4097 0 (offset 0)
# Ignoring wrong pointing object 4100 0 (offset 0)
# Ignoring wrong pointing object 4102 0 (offset 0)
# Ignoring wrong pointing object 4104 0 (offset 0)
# Ignoring wrong pointing object 4106 0 (offset 0)
# Ignoring wrong pointing object 4108 0 (offset 0)
# Ignoring wrong pointing object 4111 0 (offset 0)
# Ignoring wrong pointing object 4113 0 (offset 0)
# Ignoring wrong pointing object 4115 0 (offset 0)
# Ignoring wrong pointing object 4118 0 (offset 0)
# Ignoring wrong pointing object 4121 0 (offset 0)
# Ignoring wrong pointing object 4123 0 (offset 0)
# Ignoring wrong pointing object 4125 0 (offset 0)
# Ignoring wrong pointing object 4128 0 (offset 0)
# Ignoring wrong pointing object 4130 0 (offset 0)
# Ignoring wrong pointing object 4132 0 (offset 0)
# Ignoring wrong pointing object 4135 0 (offset 0)
# Ignoring wrong pointing object 4137 0 (offset 0)
# Ignoring wrong pointing object 4139 0 (offset 0)
# Ignoring wrong pointing object 4141 0 (offset 0)
# Ignoring wrong pointing object 4144 0 (offset 0)
# Ignoring wrong pointing object 4146 0 (offset 0)
# Ignoring wrong pointing object 4149 0 (offset 0)
# Ignoring wrong pointing object 4151 0 (offset 0)
# Ignoring wrong pointing object 4158 0 (offset 0)
# Ignoring wrong pointing object 4161 0 (offset 0)
# Ignoring wrong pointing object 4163 0 (offset 0)
# Ignoring wrong pointing object 4165 0 (offset 0)
# Ignoring wrong pointing object 4168 0 (offset 0)
# Ignoring wrong pointing object 4171 0 (offset 0)
# Ignoring wrong pointing object 4173 0 (offset 0)
# Ignoring wrong pointing object 4175 0 (offset 0)
# Ignoring wrong pointing object 4178 0 (offset 0)
# Ignoring wrong pointing object 4180 0 (offset 0)
# Ignoring wrong pointing object 4239 0 (offset 0)
# Ignoring wrong pointing object 4241 0 (offset 0)
# Ignoring wrong pointing object 4243 0 (offset 0)
# Ignoring wrong pointing object 4246 0 (offset 0)
# Ignoring wrong pointing object 4248 0 (offset 0)
# Ignoring wrong pointing object 4250 0 (offset 0)
# Ignoring wrong pointing object 4253 0 (offset 0)
# Ignoring wrong pointing object 4255 0 (offset 0)
# Ignoring wrong pointing object 4258 0 (offset 0)
# Ignoring wrong pointing object 4260 0 (offset 0)
# Ignoring wrong pointing object 4262 0 (offset 0)
# Ignoring wrong pointing object 4269 0 (offset 0)
# Ignoring wrong pointing object 4271 0 (offset 0)
# Ignoring wrong pointing object 4273 0 (offset 0)
# Ignoring wrong pointing object 4275 0 (offset 0)
# Ignoring wrong pointing object 4277 0 (offset 0)
# Ignoring wrong pointing object 4279 0 (offset 0)
# Ignoring wrong pointing object 4282 0 (offset 0)
# Ignoring wrong pointing object 4284 0 (offset 0)
# Ignoring wrong pointing object 4286 0 (offset 0)
# Ignoring wrong pointing object 4289 0 (offset 0)
# Ignoring wrong pointing object 4291 0 (offset 0)
# Ignoring wrong pointing object 4294 0 (offset 0)
# Ignoring wrong pointing object 4296 0 (offset 0)
# Ignoring wrong pointing object 4299 0 (offset 0)
# Ignoring wrong pointing object 4302 0 (offset 0)
# Ignoring wrong pointing object 4304 0 (offset 0)
# Ignoring wrong pointing object 4306 0 (offset 0)
# Ignoring wrong pointing object 4309 0 (offset 0)
# Ignoring wrong pointing object 4311 0 (offset 0)
# Ignoring wrong pointing object 4314 0 (offset 0)
# Ignoring wrong pointing object 4316 0 (offset 0)
# Ignoring wrong pointing object 4318 0 (offset 0)
# Ignoring wrong pointing object 4324 0 (offset 0)
# Ignoring wrong pointing object 4326 0 (offset 0)
# Ignoring wrong pointing object 4328 0 (offset 0)
# Ignoring wrong pointing object 4331 0 (offset 0)
# Ignoring wrong pointing object 4334 0 (offset 0)
# Ignoring wrong pointing object 4336 0 (offset 0)
# Ignoring wrong pointing object 4371 0 (offset 0)
# Ignoring wrong pointing object 4373 0 (offset 0)
# Ignoring wrong pointing object 4375 0 (offset 0)
# Ignoring wrong pointing object 4377 0 (offset 0)
# Ignoring wrong pointing object 4379 0 (offset 0)
# Ignoring wrong pointing object 4381 0 (offset 0)
# Ignoring wrong pointing object 4384 0 (offset 0)
# Ignoring wrong pointing object 4386 0 (offset 0)
# Ignoring wrong pointing object 4388 0 (offset 0)
# Ignoring wrong pointing object 4392 0 (offset 0)
# Ignoring wrong pointing object 4394 0 (offset 0)
# Ignoring wrong pointing object 4396 0 (offset 0)
# Ignoring wrong pointing object 4398 0 (offset 0)
# Ignoring wrong pointing object 4400 0 (offset 0)
# Ignoring wrong pointing object 4403 0 (offset 0)
# Ignoring wrong pointing object 4405 0 (offset 0)
# Ignoring wrong pointing object 4408 0 (offset 0)
# Ignoring wrong pointing object 4410 0 (offset 0)
# Ignoring wrong pointing object 4412 0 (offset 0)
# Ignoring wrong pointing object 4415 0 (offset 0)
# Ignoring wrong pointing object 4421 0 (offset 0)
# Ignoring wrong pointing object 4424 0 (offset 0)
# Ignoring wrong pointing object 4426 0 (offset 0)
# Ignoring wrong pointing object 4428 0 (offset 0)
# Ignoring wrong pointing object 4431 0 (offset 0)
# Ignoring wrong pointing object 4433 0 (offset 0)
# Ignoring wrong pointing object 4480 0 (offset 0)
# Ignoring wrong pointing object 4483 0 (offset 0)
# Ignoring wrong pointing object 4485 0 (offset 0)
# Ignoring wrong pointing object 4519 0 (offset 0)
# Ignoring wrong pointing object 4522 0 (offset 0)
# Ignoring wrong pointing object 4524 0 (offset 0)
# Ignoring wrong pointing object 4526 0 (offset 0)
# Ignoring wrong pointing object 4529 0 (offset 0)
# Ignoring wrong pointing object 4531 0 (offset 0)
# Ignoring wrong pointing object 4533 0 (offset 0)
# Ignoring wrong pointing object 4536 0 (offset 0)
# Ignoring wrong pointing object 4538 0 (offset 0)
# Ignoring wrong pointing object 4540 0 (offset 0)
# Ignoring wrong pointing object 4542 0 (offset 0)
# Ignoring wrong pointing object 4709 0 (offset 0)
# Ignoring wrong pointing object 4712 0 (offset 0)
# Ignoring wrong pointing object 4714 0 (offset 0)
# Ignoring wrong pointing object 4720 0 (offset 0)
# Ignoring wrong pointing object 4723 0 (offset 0)
# Ignoring wrong pointing object 4725 0 (offset 0)
# Ignoring wrong pointing object 4891 0 (offset 0)
# Ignoring wrong pointing object 4893 0 (offset 0)
# Ignoring wrong pointing object 4895 0 (offset 0)
# Ignoring wrong pointing object 4897 0 (offset 0)
# Ignoring wrong pointing object 4971 0 (offset 0)
# Ignoring wrong pointing object 4973 0 (offset 0)
# Ignoring wrong pointing object 5025 0 (offset 0)
# Ignoring wrong pointing object 5027 0 (offset 0)
# Ignoring wrong pointing object 5030 0 (offset 0)
# Ignoring wrong pointing object 5033 0 (offset 0)
# Ignoring wrong pointing object 5035 0 (offset 0)
# Ignoring wrong pointing object 5037 0 (offset 0)
# Ignoring wrong pointing object 5040 0 (offset 0)
# Ignoring wrong pointing object 5043 0 (offset 0)
# Ignoring wrong pointing object 5045 0 (offset 0)
# Ignoring wrong pointing object 5047 0 (offset 0)
# Ignoring wrong pointing object 5049 0 (offset 0)
# Ignoring wrong pointing object 5052 0 (offset 0)
# Ignoring wrong pointing object 5055 0 (offset 0)
# Ignoring wrong pointing object 5061 0 (offset 0)
# Ignoring wrong pointing object 5063 0 (offset 0)
# Ignoring wrong pointing object 5066 0 (offset 0)
# Ignoring wrong pointing object 5069 0 (offset 0)
# Ignoring wrong pointing object 5071 0 (offset 0)
# Ignoring wrong pointing object 5074 0 (offset 0)
# Ignoring wrong pointing object 5076 0 (offset 0)
# Ignoring wrong pointing object 5078 0 (offset 0)
# Ignoring wrong pointing object 5081 0 (offset 0)
# Ignoring wrong pointing object 5083 0 (offset 0)
# Ignoring wrong pointing object 5086 0 (offset 0)
# Ignoring wrong pointing object 5088 0 (offset 0)
# Ignoring wrong pointing object 5091 0 (offset 0)
# Ignoring wrong pointing object 5141 0 (offset 0)
# Ignoring wrong pointing object 5144 0 (offset 0)
# Ignoring wrong pointing object 5178 0 (offset 0)
# Ignoring wrong pointing object 5180 0 (offset 0)
# Ignoring wrong pointing object 5183 0 (offset 0)
# Ignoring wrong pointing object 5185 0 (offset 0)
# Ignoring wrong pointing object 5188 0 (offset 0)
# Ignoring wrong pointing object 5190 0 (offset 0)
# Ignoring wrong pointing object 5192 0 (offset 0)
# Ignoring wrong pointing object 5194 0 (offset 0)
# Ignoring wrong pointing object 5197 0 (offset 0)
# Ignoring wrong pointing object 5199 0 (offset 0)
# Ignoring wrong pointing object 5201 0 (offset 0)
# Ignoring wrong pointing object 5204 0 (offset 0)
# Ignoring wrong pointing object 5206 0 (offset 0)
# Ignoring wrong pointing object 5209 0 (offset 0)
# Ignoring wrong pointing object 5211 0 (offset 0)
# Ignoring wrong pointing object 5217 0 (offset 0)
# Ignoring wrong pointing object 5220 0 (offset 0)
# Ignoring wrong pointing object 5222 0 (offset 0)
# Ignoring wrong pointing object 5264 0 (offset 0)
# Ignoring wrong pointing object 5267 0 (offset 0)
# Ignoring wrong pointing object 5269 0 (offset 0)
# Ignoring wrong pointing object 5271 0 (offset 0)
# Ignoring wrong pointing object 5274 0 (offset 0)
# Ignoring wrong pointing object 5276 0 (offset 0)
# Ignoring wrong pointing object 5278 0 (offset 0)
# Ignoring wrong pointing object 5281 0 (offset 0)
# Ignoring wrong pointing object 5283 0 (offset 0)
# Ignoring wrong pointing object 5289 0 (offset 0)
# Ignoring wrong pointing object 5291 0 (offset 0)
# Ignoring wrong pointing object 5293 0 (offset 0)
# Ignoring wrong pointing object 5296 0 (offset 0)
# Ignoring wrong pointing object 5298 0 (offset 0)
# Ignoring wrong pointing object 5300 0 (offset 0)
# Ignoring wrong pointing object 5303 0 (offset 0)
# Ignoring wrong pointing object 5306 0 (offset 0)
# Ignoring wrong pointing object 5308 0 (offset 0)
# Ignoring wrong pointing object 5311 0 (offset 0)
# Ignoring wrong pointing object 5314 0 (offset 0)
# Ignoring wrong pointing object 5316 0 (offset 0)
# Ignoring wrong pointing object 5318 0 (offset 0)
# Ignoring wrong pointing object 5321 0 (offset 0)
# Ignoring wrong pointing object 5323 0 (offset 0)
# Ignoring wrong pointing object 5325 0 (offset 0)
# Ignoring wrong pointing object 5328 0 (offset 0)
# Ignoring wrong pointing object 5330 0 (offset 0)
# Ignoring wrong pointing object 5332 0 (offset 0)
# Ignoring wrong pointing object 5335 0 (offset 0)
# Ignoring wrong pointing object 5337 0 (offset 0)
# Ignoring wrong pointing object 5339 0 (offset 0)
# Ignoring wrong pointing object 5342 0 (offset 0)
# Ignoring wrong pointing object 5344 0 (offset 0)
# Ignoring wrong pointing object 5346 0 (offset 0)
# Ignoring wrong pointing object 5348 0 (offset 0)
# Ignoring wrong pointing object 5350 0 (offset 0)
# Ignoring wrong pointing object 5393 0 (offset 0)
# Ignoring wrong pointing object 5396 0 (offset 0)
# Ignoring wrong pointing object 5398 0 (offset 0)
# Ignoring wrong pointing object 5400 0 (offset 0)
# Ignoring wrong pointing object 5403 0 (offset 0)
# Ignoring wrong pointing object 5405 0 (offset 0)
# Ignoring wrong pointing object 5407 0 (offset 0)
# Ignoring wrong pointing object 5410 0 (offset 0)
# Ignoring wrong pointing object 5412 0 (offset 0)
# Ignoring wrong pointing object 5414 0 (offset 0)
# Ignoring wrong pointing object 5417 0 (offset 0)
# Ignoring wrong pointing object 5419 0 (offset 0)
# Ignoring wrong pointing object 5421 0 (offset 0)
# Ignoring wrong pointing object 5424 0 (offset 0)
# Ignoring wrong pointing object 5426 0 (offset 0)
# Ignoring wrong pointing object 5428 0 (offset 0)
# Ignoring wrong pointing object 5431 0 (offset 0)
# Ignoring wrong pointing object 5433 0 (offset 0)
# Ignoring wrong pointing object 5436 0 (offset 0)
# Ignoring wrong pointing object 5438 0 (offset 0)
# Ignoring wrong pointing object 5440 0 (offset 0)
# Ignoring wrong pointing object 5443 0 (offset 0)
# Ignoring wrong pointing object 5445 0 (offset 0)
# Ignoring wrong pointing object 5448 0 (offset 0)
# Ignoring wrong pointing object 5450 0 (offset 0)
# Ignoring wrong pointing object 5453 0 (offset 0)
# Ignoring wrong pointing object 5455 0 (offset 0)
# Ignoring wrong pointing object 5457 0 (offset 0)
# Ignoring wrong pointing object 5460 0 (offset 0)
# Ignoring wrong pointing object 5462 0 (offset 0)
# Ignoring wrong pointing object 5537 0 (offset 0)
# Ignoring wrong pointing object 5540 0 (offset 0)
# Ignoring wrong pointing object 5542 0 (offset 0)
# Ignoring wrong pointing object 5544 0 (offset 0)
# Ignoring wrong pointing object 5547 0 (offset 0)
# Ignoring wrong pointing object 5549 0 (offset 0)
# Ignoring wrong pointing object 5768 0 (offset 0)
# Ignoring wrong pointing object 5771 0 (offset 0)
# Ignoring wrong pointing object 5773 0 (offset 0)
# Ignoring wrong pointing object 5775 0 (offset 0)
# Ignoring wrong pointing object 5778 0 (offset 0)
# Ignoring wrong pointing object 5780 0 (offset 0)
# Ignoring wrong pointing object 5782 0 (offset 0)
# Ignoring wrong pointing object 5785 0 (offset 0)
# Ignoring wrong pointing object 5787 0 (offset 0)
# Ignoring wrong pointing object 5793 0 (offset 0)
# Ignoring wrong pointing object 5795 0 (offset 0)
# Ignoring wrong pointing object 5798 0 (offset 0)
# Ignoring wrong pointing object 5800 0 (offset 0)
# Ignoring wrong pointing object 5802 0 (offset 0)
# Ignoring wrong pointing object 5806 0 (offset 0)
# Ignoring wrong pointing object 5808 0 (offset 0)
# Ignoring wrong pointing object 5810 0 (offset 0)
# Ignoring wrong pointing object 5813 0 (offset 0)
# Ignoring wrong pointing object 5815 0 (offset 0)
# Ignoring wrong pointing object 5817 0 (offset 0)
# Ignoring wrong pointing object 5819 0 (offset 0)
# Ignoring wrong pointing object 5821 0 (offset 0)
# Ignoring wrong pointing object 5824 0 (offset 0)
# Ignoring wrong pointing object 5827 0 (offset 0)
# Ignoring wrong pointing object 5829 0 (offset 0)
# Ignoring wrong pointing object 5831 0 (offset 0)
# Ignoring wrong pointing object 5833 0 (offset 0)
# Ignoring wrong pointing object 5836 0 (offset 0)
# Ignoring wrong pointing object 5838 0 (offset 0)
# Ignoring wrong pointing object 5840 0 (offset 0)
# Ignoring wrong pointing object 5847 0 (offset 0)
# Ignoring wrong pointing object 5849 0 (offset 0)
# Ignoring wrong pointing object 5851 0 (offset 0)
# Ignoring wrong pointing object 5854 0 (offset 0)
# Ignoring wrong pointing object 5861 0 (offset 0)
# Ignoring wrong pointing object 5863 0 (offset 0)
# Ignoring wrong pointing object 5865 0 (offset 0)
# Ignoring wrong pointing object 5867 0 (offset 0)
# Ignoring wrong pointing object 5870 0 (offset 0)
# Ignoring wrong pointing object 5872 0 (offset 0)
# Ignoring wrong pointing object 5874 0 (offset 0)
# Ignoring wrong pointing object 5877 0 (offset 0)
# Ignoring wrong pointing object 5879 0 (offset 0)
# Ignoring wrong pointing object 5882 0 (offset 0)
# Ignoring wrong pointing object 5884 0 (offset 0)
# Ignoring wrong pointing object 5886 0 (offset 0)
# Ignoring wrong pointing object 5889 0 (offset 0)
# Ignoring wrong pointing object 5891 0 (offset 0)
# Ignoring wrong pointing object 5893 0 (offset 0)
# Ignoring wrong pointing object 5896 0 (offset 0)
# Ignoring wrong pointing object 5898 0 (offset 0)
# Ignoring wrong pointing object 5900 0 (offset 0)
# Ignoring wrong pointing object 5902 0 (offset 0)
# Ignoring wrong pointing object 5904 0 (offset 0)
# Ignoring wrong pointing object 5907 0 (offset 0)
# Ignoring wrong pointing object 5909 0 (offset 0)
# Ignoring wrong pointing object 5911 0 (offset 0)
# Ignoring wrong pointing object 5913 0 (offset 0)
# Ignoring wrong pointing object 5917 0 (offset 0)
# Ignoring wrong pointing object 5919 0 (offset 0)
# Ignoring wrong pointing object 5921 0 (offset 0)
# Ignoring wrong pointing object 5927 0 (offset 0)
# Ignoring wrong pointing object 5929 0 (offset 0)
# Ignoring wrong pointing object 5935 0 (offset 0)
# Ignoring wrong pointing object 5937 0 (offset 0)
# Ignoring wrong pointing object 5939 0 (offset 0)
# Ignoring wrong pointing object 5943 0 (offset 0)
# Ignoring wrong pointing object 5945 0 (offset 0)
# Ignoring wrong pointing object 5947 0 (offset 0)
# Ignoring wrong pointing object 5949 0 (offset 0)
# Ignoring wrong pointing object 5951 0 (offset 0)
# Ignoring wrong pointing object 5954 0 (offset 0)
# Ignoring wrong pointing object 5956 0 (offset 0)
# Ignoring wrong pointing object 5958 0 (offset 0)
# Ignoring wrong pointing object 5964 0 (offset 0)
# Ignoring wrong pointing object 6031 0 (offset 0)
# Ignoring wrong pointing object 6033 0 (offset 0)
# Ignoring wrong pointing object 6035 0 (offset 0)
# Ignoring wrong pointing object 6038 0 (offset 0)
# Ignoring wrong pointing object 6040 0 (offset 0)
# Ignoring wrong pointing object 6042 0 (offset 0)
# Ignoring wrong pointing object 6044 0 (offset 0)
# Ignoring wrong pointing object 6046 0 (offset 0)
# Ignoring wrong pointing object 6048 0 (offset 0)
# Ignoring wrong pointing object 6051 0 (offset 0)
# Ignoring wrong pointing object 6054 0 (offset 0)
# Ignoring wrong pointing object 6056 0 (offset 0)
# Ignoring wrong pointing object 6058 0 (offset 0)
# Ignoring wrong pointing object 6060 0 (offset 0)
# Ignoring wrong pointing object 6062 0 (offset 0)
# Ignoring wrong pointing object 6065 0 (offset 0)
# Ignoring wrong pointing object 6067 0 (offset 0)
# Ignoring wrong pointing object 6070 0 (offset 0)
# Ignoring wrong pointing object 6072 0 (offset 0)
# Ignoring wrong pointing object 6110 0 (offset 0)
# Ignoring wrong pointing object 6113 0 (offset 0)
# Ignoring wrong pointing object 6115 0 (offset 0)
# Ignoring wrong pointing object 6117 0 (offset 0)
# Ignoring wrong pointing object 6119 0 (offset 0)
# Ignoring wrong pointing object 6121 0 (offset 0)
# Ignoring wrong pointing object 6123 0 (offset 0)
# Ignoring wrong pointing object 6125 0 (offset 0)
# Ignoring wrong pointing object 6127 0 (offset 0)
# Ignoring wrong pointing object 6130 0 (offset 0)
# Ignoring wrong pointing object 6133 0 (offset 0)
# Ignoring wrong pointing object 6135 0 (offset 0)
# Ignoring wrong pointing object 6137 0 (offset 0)
# Ignoring wrong pointing object 6139 0 (offset 0)
# Ignoring wrong pointing object 6141 0 (offset 0)
# Ignoring wrong pointing object 6143 0 (offset 0)
# Ignoring wrong pointing object 6200 0 (offset 0)
# Ignoring wrong pointing object 6202 0 (offset 0)
# Ignoring wrong pointing object 6204 0 (offset 0)
# Ignoring wrong pointing object 6206 0 (offset 0)
# Ignoring wrong pointing object 6209 0 (offset 0)
# Ignoring wrong pointing object 6211 0 (offset 0)
# Ignoring wrong pointing object 6258 0 (offset 0)
# Ignoring wrong pointing object 6260 0 (offset 0)
# Ignoring wrong pointing object 6262 0 (offset 0)
# Ignoring wrong pointing object 6265 0 (offset 0)
# Ignoring wrong pointing object 6267 0 (offset 0)
# Ignoring wrong pointing object 6269 0 (offset 0)
# Ignoring wrong pointing object 6271 0 (offset 0)
# Ignoring wrong pointing object 6274 0 (offset 0)
# Ignoring wrong pointing object 6277 0 (offset 0)
# Ignoring wrong pointing object 6279 0 (offset 0)
# Ignoring wrong pointing object 6281 0 (offset 0)
# Ignoring wrong pointing object 6472 0 (offset 0)
# Ignoring wrong pointing object 6475 0 (offset 0)
# Ignoring wrong pointing object 6477 0 (offset 0)
# Ignoring wrong pointing object 6479 0 (offset 0)
# Ignoring wrong pointing object 6482 0 (offset 0)
# Ignoring wrong pointing object 6484 0 (offset 0)
# Ignoring wrong pointing object 6486 0 (offset 0)
# Ignoring wrong pointing object 6488 0 (offset 0)
# Ignoring wrong pointing object 6491 0 (offset 0)
# Ignoring wrong pointing object 6494 0 (offset 0)
# Ignoring wrong pointing object 6496 0 (offset 0)
# Ignoring wrong pointing object 6498 0 (offset 0)
# Ignoring wrong pointing object 6500 0 (offset 0)
# Ignoring wrong pointing object 6504 0 (offset 0)
# Ignoring wrong pointing object 6506 0 (offset 0)
# Ignoring wrong pointing object 6508 0 (offset 0)
# Ignoring wrong pointing object 6510 0 (offset 0)
# Ignoring wrong pointing object 6513 0 (offset 0)
# Ignoring wrong pointing object 6520 0 (offset 0)
# Ignoring wrong pointing object 6522 0 (offset 0)
# Ignoring wrong pointing object 6524 0 (offset 0)
# Ignoring wrong pointing object 6526 0 (offset 0)
# Ignoring wrong pointing object 6528 0 (offset 0)
# Ignoring wrong pointing object 6531 0 (offset 0)
# Ignoring wrong pointing object 6533 0 (offset 0)
# Ignoring wrong pointing object 6536 0 (offset 0)
# Ignoring wrong pointing object 6538 0 (offset 0)
# Ignoring wrong pointing object 6541 0 (offset 0)
# Ignoring wrong pointing object 6595 0 (offset 0)
# Ignoring wrong pointing object 6597 0 (offset 0)
# Ignoring wrong pointing object 6600 0 (offset 0)
# Ignoring wrong pointing object 6607 0 (offset 0)
# Ignoring wrong pointing object 6609 0 (offset 0)
# Ignoring wrong pointing object 6611 0 (offset 0)
# Ignoring wrong pointing object 6710 0 (offset 0)
# Ignoring wrong pointing object 6712 0 (offset 0)
# Ignoring wrong pointing object 6714 0 (offset 0)
# Ignoring wrong pointing object 6873 0 (offset 0)
# Ignoring wrong pointing object 6875 0 (offset 0)
# Ignoring wrong pointing object 6878 0 (offset 0)
# Ignoring wrong pointing object 6880 0 (offset 0)
# Ignoring wrong pointing object 6883 0 (offset 0)
# Ignoring wrong pointing object 6885 0 (offset 0)
# Ignoring wrong pointing object 6888 0 (offset 0)
# Ignoring wrong pointing object 6890 0 (offset 0)
# Ignoring wrong pointing object 7106 0 (offset 0)
# Ignoring wrong pointing object 7108 0 (offset 0)
# Ignoring wrong pointing object 7111 0 (offset 0)
# Ignoring wrong pointing object 7117 0 (offset 0)
# Ignoring wrong pointing object 7119 0 (offset 0)
# Ignoring wrong pointing object 7122 0 (offset 0)
# Ignoring wrong pointing object 7124 0 (offset 0)
# Ignoring wrong pointing object 7127 0 (offset 0)
# Ignoring wrong pointing object 7129 0 (offset 0)
# Ignoring wrong pointing object 7131 0 (offset 0)
# Ignoring wrong pointing object 7133 0 (offset 0)
# Ignoring wrong pointing object 7136 0 (offset 0)
# Ignoring wrong pointing object 7138 0 (offset 0)
# Ignoring wrong pointing object 7140 0 (offset 0)
# Ignoring wrong pointing object 7142 0 (offset 0)
# Ignoring wrong pointing object 7144 0 (offset 0)
# Ignoring wrong pointing object 7147 0 (offset 0)
# Ignoring wrong pointing object 7149 0 (offset 0)
# Ignoring wrong pointing object 7151 0 (offset 0)
# Ignoring wrong pointing object 7155 0 (offset 0)
# Ignoring wrong pointing object 7157 0 (offset 0)
# Ignoring wrong pointing object 7159 0 (offset 0)
# Ignoring wrong pointing object 7161 0 (offset 0)
# Ignoring wrong pointing object 7163 0 (offset 0)
# Ignoring wrong pointing object 7167 0 (offset 0)
# Ignoring wrong pointing object 7169 0 (offset 0)
# Ignoring wrong pointing object 7171 0 (offset 0)
# Ignoring wrong pointing object 7173 0 (offset 0)
# Ignoring wrong pointing object 7175 0 (offset 0)
# Ignoring wrong pointing object 7179 0 (offset 0)
# Ignoring wrong pointing object 7181 0 (offset 0)
# Ignoring wrong pointing object 7183 0 (offset 0)
# Ignoring wrong pointing object 7185 0 (offset 0)
# Ignoring wrong pointing object 7187 0 (offset 0)
# Ignoring wrong pointing object 7191 0 (offset 0)
# Ignoring wrong pointing object 7193 0 (offset 0)
# Ignoring wrong pointing object 7195 0 (offset 0)
# Ignoring wrong pointing object 7197 0 (offset 0)
# Ignoring wrong pointing object 7199 0 (offset 0)
# Ignoring wrong pointing object 7203 0 (offset 0)
# Ignoring wrong pointing object 7205 0 (offset 0)
# Ignoring wrong pointing object 7207 0 (offset 0)
# Ignoring wrong pointing object 7209 0 (offset 0)
# Ignoring wrong pointing object 7211 0 (offset 0)
# Ignoring wrong pointing object 7215 0 (offset 0)
# Ignoring wrong pointing object 7217 0 (offset 0)
# Ignoring wrong pointing object 7219 0 (offset 0)
# Ignoring wrong pointing object 7221 0 (offset 0)
# Ignoring wrong pointing object 7223 0 (offset 0)
# Ignoring wrong pointing object 7227 0 (offset 0)
# Ignoring wrong pointing object 7229 0 (offset 0)
# Ignoring wrong pointing object 7231 0 (offset 0)
# Ignoring wrong pointing object 7233 0 (offset 0)
# Ignoring wrong pointing object 7235 0 (offset 0)
# Ignoring wrong pointing object 7242 0 (offset 0)
# Ignoring wrong pointing object 7245 0 (offset 0)
# Ignoring wrong pointing object 7247 0 (offset 0)
# Ignoring wrong pointing object 7249 0 (offset 0)
# Ignoring wrong pointing object 7251 0 (offset 0)
# Ignoring wrong pointing object 7254 0 (offset 0)
# Ignoring wrong pointing object 7256 0 (offset 0)
# Ignoring wrong pointing object 7259 0 (offset 0)
# Ignoring wrong pointing object 7261 0 (offset 0)
# Ignoring wrong pointing object 7264 0 (offset 0)
# Ignoring wrong pointing object 7266 0 (offset 0)
# Ignoring wrong pointing object 7434 0 (offset 0)
# Ignoring wrong pointing object 7436 0 (offset 0)
# Ignoring wrong pointing object 7438 0 (offset 0)
# Ignoring wrong pointing object 7440 0 (offset 0)
# Ignoring wrong pointing object 7478 0 (offset 0)
# Ignoring wrong pointing object 7480 0 (offset 0)
# Ignoring wrong pointing object 7483 0 (offset 0)
# Ignoring wrong pointing object 7545 0 (offset 0)
# Ignoring wrong pointing object 7548 0 (offset 0)
# Ignoring wrong pointing object 7550 0 (offset 0)
# Ignoring wrong pointing object 7552 0 (offset 0)
# Ignoring wrong pointing object 7554 0 (offset 0)
# Ignoring wrong pointing object 7556 0 (offset 0)
# Ignoring wrong pointing object 7558 0 (offset 0)
# Ignoring wrong pointing object 7569 0 (offset 0)
# Ignoring wrong pointing object 7571 0 (offset 0)
# Ignoring wrong pointing object 7573 0 (offset 0)
# Ignoring wrong pointing object 7575 0 (offset 0)
# Ignoring wrong pointing object 7907 0 (offset 0)
# Ignoring wrong pointing object 7909 0 (offset 0)
# Ignoring wrong pointing object 7911 0 (offset 0)
# Ignoring wrong pointing object 7914 0 (offset 0)
# Ignoring wrong pointing object 7916 0 (offset 0)
# Ignoring wrong pointing object 7919 0 (offset 0)
# Ignoring wrong pointing object 7921 0 (offset 0)
# Ignoring wrong pointing object 7923 0 (offset 0)
# Ignoring wrong pointing object 7926 0 (offset 0)
# Ignoring wrong pointing object 7928 0 (offset 0)
# ...
# Ignoring wrong pointing object 9919 0 (offset 0)
# Ignoring wrong pointing object 9921 0 (offset 0)
# Ignoring wrong pointing object 9923 0 (offset 0)
# Ignoring wrong pointing object 9925 0 (offset 0)
# Ignoring wrong pointing object 9931 0 (offset 0)
# Ignoring wrong pointing object 9934 0 (offset 0)
# Ignoring wrong pointing object 9936 0 (offset 0)
# Ignoring wrong pointing object 9938 0 (offset 0)
# Ignoring wrong pointing object 9940 0 (offset 0)
# Ignoring wrong pointing object 9942 0 (offset 0)
# Ignoring wrong pointing object 9944 0 (offset 0)
# Ignoring wrong pointing object 9946 0 (offset 0)
# Ignoring wrong pointing object 9949 0 (offset 0)
# Ignoring wrong pointing object 9951 0 (offset 0)
# Ignoring wrong pointing object 9953 0 (offset 0)
# Ignoring wrong pointing object 9960 0 (offset 0)
# Ignoring wrong pointing object 9962 0 (offset 0)
# Ignoring wrong pointing object 9964 0 (offset 0)
# Ignoring wrong pointing object 10123 0 (offset 0)
# Ignoring wrong pointing object 10196 0 (offset 0)
# Ignoring wrong pointing object 10259 0 (offset 0)
# Ignoring wrong pointing object 10261 0 (offset 0)
# Ignoring wrong pointing object 10264 0 (offset 0)
# Ignoring wrong pointing object 10266 0 (offset 0)
# Ignoring wrong pointing object 10292 0 (offset 0)
# Ignoring wrong pointing object 10294 0 (offset 0)
# Ignoring wrong pointing object 10296 0 (offset 0)
# Ignoring wrong pointing object 10299 0 (offset 0)
# Ignoring wrong pointing object 10301 0 (offset 0)
# Ignoring wrong pointing object 10303 0 (offset 0)
# Ignoring wrong pointing object 10305 0 (offset 0)
# Ignoring wrong pointing object 10307 0 (offset 0)
# Ignoring wrong pointing object 10309 0 (offset 0)
# Ignoring wrong pointing object 10312 0 (offset 0)
# Ignoring wrong pointing object 10314 0 (offset 0)
# Ignoring wrong pointing object 10396 0 (offset 0)
# Ignoring wrong pointing object 10398 0 (offset 0)
# Ignoring wrong pointing object 10400 0 (offset 0)
# Ignoring wrong pointing object 10403 0 (offset 0)
# Ignoring wrong pointing object 10405 0 (offset 0)
# Ignoring wrong pointing object 10408 0 (offset 0)
# Ignoring wrong pointing object 10410 0 (offset 0)
# Ignoring wrong pointing object 10412 0 (offset 0)
# Ignoring wrong pointing object 10414 0 (offset 0)
# Ignoring wrong pointing object 10416 0 (offset 0)
# Ignoring wrong pointing object 10418 0 (offset 0)
# Ignoring wrong pointing object 10420 0 (offset 0)
# Ignoring wrong pointing object 10423 0 (offset 0)
# Ignoring wrong pointing object 10425 0 (offset 0)
# Ignoring wrong pointing object 10428 0 (offset 0)
# Ignoring wrong pointing object 10430 0 (offset 0)
# Ignoring wrong pointing object 10432 0 (offset 0)
# Ignoring wrong pointing object 10434 0 (offset 0)
# Ignoring wrong pointing object 10437 0 (offset 0)
# Ignoring wrong pointing object 10439 0 (offset 0)
# Ignoring wrong pointing object 10441 0 (offset 0)
# Ignoring wrong pointing object 10443 0 (offset 0)
# Ignoring wrong pointing object 10445 0 (offset 0)
# Ignoring wrong pointing object 10448 0 (offset 0)
# Ignoring wrong pointing object 10454 0 (offset 0)
# Ignoring wrong pointing object 10457 0 (offset 0)
# Ignoring wrong pointing object 10459 0 (offset 0)
# Ignoring wrong pointing object 10461 0 (offset 0)
# Ignoring wrong pointing object 10464 0 (offset 0)
# Ignoring wrong pointing object 10466 0 (offset 0)
# Ignoring wrong pointing object 10468 0 (offset 0)
# Ignoring wrong pointing object 10470 0 (offset 0)
# Ignoring wrong pointing object 10472 0 (offset 0)
# Ignoring wrong pointing object 10475 0 (offset 0)
# Ignoring wrong pointing object 10477 0 (offset 0)
# Ignoring wrong pointing object 10480 0 (offset 0)
# Ignoring wrong pointing object 10482 0 (offset 0)
# Ignoring wrong pointing object 10484 0 (offset 0)
# Ignoring wrong pointing object 10486 0 (offset 0)
# Ignoring wrong pointing object 10612 0 (offset 0)
# Ignoring wrong pointing object 10614 0 (offset 0)
# Ignoring wrong pointing object 10617 0 (offset 0)
# Ignoring wrong pointing object 10619 0 (offset 0)
# Ignoring wrong pointing object 10622 0 (offset 0)
# Ignoring wrong pointing object 10624 0 (offset 0)
# Ignoring wrong pointing object 10627 0 (offset 0)
# Ignoring wrong pointing object 10629 0 (offset 0)
# Ignoring wrong pointing object 10632 0 (offset 0)
# Ignoring wrong pointing object 10634 0 (offset 0)
# Ignoring wrong pointing object 10642 0 (offset 0)
# Ignoring wrong pointing object 10644 0 (offset 0)
# Ignoring wrong pointing object 10647 0 (offset 0)
# Ignoring wrong pointing object 10649 0 (offset 0)
# Ignoring wrong pointing object 10652 0 (offset 0)
# Ignoring wrong pointing object 10654 0 (offset 0)
# Ignoring wrong pointing object 10657 0 (offset 0)
# Ignoring wrong pointing object 10659 0 (offset 0)
# Ignoring wrong pointing object 10662 0 (offset 0)
# Ignoring wrong pointing object 10664 0 (offset 0)
# Ignoring wrong pointing object 10667 0 (offset 0)
# Ignoring wrong pointing object 10669 0 (offset 0)
# Ignoring wrong pointing object 10672 0 (offset 0)
# Ignoring wrong pointing object 10674 0 (offset 0)
# Ignoring wrong pointing object 10677 0 (offset 0)
# Ignoring wrong pointing object 10679 0 (offset 0)
# Ignoring wrong pointing object 10682 0 (offset 0)
# Ignoring wrong pointing object 10684 0 (offset 0)
# Ignoring wrong pointing object 10687 0 (offset 0)
# Ignoring wrong pointing object 10689 0 (offset 0)
# Ignoring wrong pointing object 10691 0 (offset 0)
# Ignoring wrong pointing object 10693 0 (offset 0)
# Ignoring wrong pointing object 10695 0 (offset 0)
# Ignoring wrong pointing object 10753 0 (offset 0)
# Ignoring wrong pointing object 10756 0 (offset 0)
# Ignoring wrong pointing object 10758 0 (offset 0)
# Ignoring wrong pointing object 10760 0 (offset 0)
# Ignoring wrong pointing object 10762 0 (offset 0)
# Ignoring wrong pointing object 10764 0 (offset 0)
# Ignoring wrong pointing object 10767 0 (offset 0)
# Ignoring wrong pointing object 10769 0 (offset 0)
# Ignoring wrong pointing object 10771 0 (offset 0)
# Ignoring wrong pointing object 10815 0 (offset 0)
# Ignoring wrong pointing object 10817 0 (offset 0)
# Ignoring wrong pointing object 10825 0 (offset 0)
# Ignoring wrong pointing object 10827 0 (offset 0)
# Ignoring wrong pointing object 10829 0 (offset 0)
# Ignoring wrong pointing object 10835 0 (offset 0)
# Ignoring wrong pointing object 10837 0 (offset 0)
# Ignoring wrong pointing object 10985 0 (offset 0)
# Ignoring wrong pointing object 11174 0 (offset 0)
# Ignoring wrong pointing object 11176 0 (offset 0)
# Ignoring wrong pointing object 11179 0 (offset 0)
# Ignoring wrong pointing object 11181 0 (offset 0)
# Ignoring wrong pointing object 11184 0 (offset 0)
# Ignoring wrong pointing object 11186 0 (offset 0)
# Ignoring wrong pointing object 11189 0 (offset 0)
# Ignoring wrong pointing object 11191 0 (offset 0)
# Ignoring wrong pointing object 11194 0 (offset 0)
# Ignoring wrong pointing object 11196 0 (offset 0)
# Ignoring wrong pointing object 11199 0 (offset 0)
# Ignoring wrong pointing object 11201 0 (offset 0)
# Ignoring wrong pointing object 11203 0 (offset 0)
# Ignoring wrong pointing object 11205 0 (offset 0)
# Ignoring wrong pointing object 11208 0 (offset 0)
# Ignoring wrong pointing object 11215 0 (offset 0)
# Ignoring wrong pointing object 11217 0 (offset 0)
# Ignoring wrong pointing object 11220 0 (offset 0)
# Ignoring wrong pointing object 11222 0 (offset 0)
# Ignoring wrong pointing object 11225 0 (offset 0)
# Ignoring wrong pointing object 11227 0 (offset 0)
# Ignoring wrong pointing object 11230 0 (offset 0)
# Ignoring wrong pointing object 11232 0 (offset 0)
# Ignoring wrong pointing object 11235 0 (offset 0)
# Ignoring wrong pointing object 11237 0 (offset 0)
# Ignoring wrong pointing object 11240 0 (offset 0)
# Ignoring wrong pointing object 11242 0 (offset 0)
# Ignoring wrong pointing object 11245 0 (offset 0)
# Ignoring wrong pointing object 11247 0 (offset 0)
# Ignoring wrong pointing object 11250 0 (offset 0)
# Ignoring wrong pointing object 11252 0 (offset 0)
# Ignoring wrong pointing object 11255 0 (offset 0)
# Ignoring wrong pointing object 11257 0 (offset 0)
# Ignoring wrong pointing object 11260 0 (offset 0)
# Ignoring wrong pointing object 11262 0 (offset 0)
# Ignoring wrong pointing object 11265 0 (offset 0)
# Ignoring wrong pointing object 11267 0 (offset 0)
# Ignoring wrong pointing object 11338 0 (offset 0)
# Ignoring wrong pointing object 11340 0 (offset 0)
# Ignoring wrong pointing object 11343 0 (offset 0)
# Ignoring wrong pointing object 11345 0 (offset 0)
# Ignoring wrong pointing object 11347 0 (offset 0)
# Ignoring wrong pointing object 11350 0 (offset 0)
# Ignoring wrong pointing object 11352 0 (offset 0)
# Ignoring wrong pointing object 11354 0 (offset 0)
# Ignoring wrong pointing object 11357 0 (offset 0)
# Ignoring wrong pointing object 11359 0 (offset 0)
# Ignoring wrong pointing object 11361 0 (offset 0)
# Ignoring wrong pointing object 11363 0 (offset 0)
# Ignoring wrong pointing object 11366 0 (offset 0)
# Ignoring wrong pointing object 11368 0 (offset 0)
# Ignoring wrong pointing object 11370 0 (offset 0)
# Ignoring wrong pointing object 11376 0 (offset 0)
# Ignoring wrong pointing object 11379 0 (offset 0)
# Ignoring wrong pointing object 11381 0 (offset 0)
# Ignoring wrong pointing object 11383 0 (offset 0)
# Ignoring wrong pointing object 11386 0 (offset 0)
# Ignoring wrong pointing object 11388 0 (offset 0)
# Ignoring wrong pointing object 11390 0 (offset 0)
# Ignoring wrong pointing object 11393 0 (offset 0)
# Ignoring wrong pointing object 11395 0 (offset 0)
# Ignoring wrong pointing object 11397 0 (offset 0)
# Ignoring wrong pointing object 11403 0 (offset 0)
# Ignoring wrong pointing object 11406 0 (offset 0)
# Ignoring wrong pointing object 11408 0 (offset 0)
# Ignoring wrong pointing object 11410 0 (offset 0)
# Ignoring wrong pointing object 11412 0 (offset 0)
# Ignoring wrong pointing object 11415 0 (offset 0)
# Ignoring wrong pointing object 11417 0 (offset 0)
# Ignoring wrong pointing object 11419 0 (offset 0)
# Ignoring wrong pointing object 11422 0 (offset 0)
# Ignoring wrong pointing object 11424 0 (offset 0)
# Ignoring wrong pointing object 11426 0 (offset 0)
# Ignoring wrong pointing object 11429 0 (offset 0)
# Ignoring wrong pointing object 11431 0 (offset 0)
# Ignoring wrong pointing object 11433 0 (offset 0)
# Ignoring wrong pointing object 11439 0 (offset 0)
# Ignoring wrong pointing object 11442 0 (offset 0)
# Ignoring wrong pointing object 11444 0 (offset 0)
# Ignoring wrong pointing object 11446 0 (offset 0)
# Ignoring wrong pointing object 11449 0 (offset 0)
# Ignoring wrong pointing object 11451 0 (offset 0)
# Ignoring wrong pointing object 11457 0 (offset 0)
# Ignoring wrong pointing object 11460 0 (offset 0)
# Ignoring wrong pointing object 11462 0 (offset 0)
# Ignoring wrong pointing object 11464 0 (offset 0)
# Ignoring wrong pointing object 11466 0 (offset 0)
# Ignoring wrong pointing object 11469 0 (offset 0)
# Ignoring wrong pointing object 11471 0 (offset 0)
# Ignoring wrong pointing object 11473 0 (offset 0)
# Ignoring wrong pointing object 11475 0 (offset 0)
# Ignoring wrong pointing object 11478 0 (offset 0)
# Ignoring wrong pointing object 11480 0 (offset 0)
# Ignoring wrong pointing object 11482 0 (offset 0)
# Ignoring wrong pointing object 11484 0 (offset 0)
# Ignoring wrong pointing object 11487 0 (offset 0)
# Ignoring wrong pointing object 11489 0 (offset 0)
# Ignoring wrong pointing object 11491 0 (offset 0)
# Ignoring wrong pointing object 11505 0 (offset 0)
# Ignoring wrong pointing object 11507 0 (offset 0)
# Ignoring wrong pointing object 11509 0 (offset 0)
# Ignoring wrong pointing object 11512 0 (offset 0)
# Ignoring wrong pointing object 11514 0 (offset 0)
# Ignoring wrong pointing object 11517 0 (offset 0)
# Ignoring wrong pointing object 11519 0 (offset 0)
# Ignoring wrong pointing object 11522 0 (offset 0)
# Ignoring wrong pointing object 11524 0 (offset 0)
# Ignoring wrong pointing object 11527 0 (offset 0)
# Ignoring wrong pointing object 11529 0 (offset 0)
# Ignoring wrong pointing object 11531 0 (offset 0)
# Ignoring wrong pointing object 11534 0 (offset 0)
# Ignoring wrong pointing object 11536 0 (offset 0)
# Ignoring wrong pointing object 11543 0 (offset 0)
# Ignoring wrong pointing object 11546 0 (offset 0)
# Ignoring wrong pointing object 11548 0 (offset 0)
# Ignoring wrong pointing object 11550 0 (offset 0)
# Ignoring wrong pointing object 11553 0 (offset 0)
# Ignoring wrong pointing object 11555 0 (offset 0)
# Ignoring wrong pointing object 11557 0 (offset 0)
# Ignoring wrong pointing object 11564 0 (offset 0)
# Ignoring wrong pointing object 11566 0 (offset 0)
# Ignoring wrong pointing object 11568 0 (offset 0)
# Ignoring wrong pointing object 12027 0 (offset 0)
# Ignoring wrong pointing object 12348 0 (offset 0)
# Ignoring wrong pointing object 12350 0 (offset 0)
# Ignoring wrong pointing object 12486 0 (offset 0)
# Ignoring wrong pointing object 12513 0 (offset 0)
# Ignoring wrong pointing object 12515 0 (offset 0)
# Ignoring wrong pointing object 12518 0 (offset 0)
# Ignoring wrong pointing object 12520 0 (offset 0)
# Ignoring wrong pointing object 12523 0 (offset 0)
# Ignoring wrong pointing object 12525 0 (offset 0)
# Ignoring wrong pointing object 12528 0 (offset 0)
# Ignoring wrong pointing object 12531 0 (offset 0)
# Ignoring wrong pointing object 12533 0 (offset 0)
# Ignoring wrong pointing object 12535 0 (offset 0)
# Ignoring wrong pointing object 12538 0 (offset 0)
# Ignoring wrong pointing object 12540 0 (offset 0)
# Ignoring wrong pointing object 12542 0 (offset 0)
# Ignoring wrong pointing object 12545 0 (offset 0)
# Ignoring wrong pointing object 12547 0 (offset 0)
# Ignoring wrong pointing object 12549 0 (offset 0)
# Ignoring wrong pointing object 12552 0 (offset 0)
# Ignoring wrong pointing object 12554 0 (offset 0)
# Ignoring wrong pointing object 12561 0 (offset 0)
# Ignoring wrong pointing object 12563 0 (offset 0)
# Ignoring wrong pointing object 12570 0 (offset 0)
# Ignoring wrong pointing object 12572 0 (offset 0)
# Ignoring wrong pointing object 12575 0 (offset 0)
# Ignoring wrong pointing object 12577 0 (offset 0)
# Ignoring wrong pointing object 12580 0 (offset 0)
# Ignoring wrong pointing object 12582 0 (offset 0)
# Ignoring wrong pointing object 12585 0 (offset 0)
# Ignoring wrong pointing object 12588 0 (offset 0)
# Ignoring wrong pointing object 12590 0 (offset 0)
# Ignoring wrong pointing object 12592 0 (offset 0)
# Ignoring wrong pointing object 12595 0 (offset 0)
# Ignoring wrong pointing object 12597 0 (offset 0)
# Ignoring wrong pointing object 12599 0 (offset 0)
# Ignoring wrong pointing object 12602 0 (offset 0)
# Ignoring wrong pointing object 12604 0 (offset 0)
# Ignoring wrong pointing object 12606 0 (offset 0)
# Ignoring wrong pointing object 12608 0 (offset 0)
# Ignoring wrong pointing object 12610 0 (offset 0)
# Ignoring wrong pointing object 12612 0 (offset 0)
# Ignoring wrong pointing object 12615 0 (offset 0)
# Ignoring wrong pointing object 12617 0 (offset 0)
# Ignoring wrong pointing object 12619 0 (offset 0)
# Ignoring wrong pointing object 12622 0 (offset 0)
# Ignoring wrong pointing object 12624 0 (offset 0)
# Ignoring wrong pointing object 12627 0 (offset 0)
# Ignoring wrong pointing object 12633 0 (offset 0)
# Ignoring wrong pointing object 12635 0 (offset 0)
# Ignoring wrong pointing object 12637 0 (offset 0)
# Ignoring wrong pointing object 12640 0 (offset 0)
# Ignoring wrong pointing object 12642 0 (offset 0)
# Ignoring wrong pointing object 12645 0 (offset 0)
# Ignoring wrong pointing object 12647 0 (offset 0)
# Ignoring wrong pointing object 12649 0 (offset 0)
# Ignoring wrong pointing object 12652 0 (offset 0)
# Ignoring wrong pointing object 12654 0 (offset 0)
# Ignoring wrong pointing object 12656 0 (offset 0)
# Ignoring wrong pointing object 12659 0 (offset 0)
# Ignoring wrong pointing object 12662 0 (offset 0)
# Ignoring wrong pointing object 12664 0 (offset 0)
# Ignoring wrong pointing object 12666 0 (offset 0)
# Ignoring wrong pointing object 12668 0 (offset 0)
# Ignoring wrong pointing object 12671 0 (offset 0)
# Ignoring wrong pointing object 12673 0 (offset 0)
# Ignoring wrong pointing object 12675 0 (offset 0)
# Ignoring wrong pointing object 12677 0 (offset 0)
# Ignoring wrong pointing object 12680 0 (offset 0)
# Ignoring wrong pointing object 12682 0 (offset 0)
# Ignoring wrong pointing object 12684 0 (offset 0)
# Successfully processed and embedded: МоделюванняСистемНавчПосібник_2011.pdf

# %% [markdown]
# ### Task 2 - Q&A Assistant

# %% [markdown]
# Gemini was selected for its free benefits for students.

# %% [markdown]
# >Create an LLM prompt template that contains:
# >- a task definition;
# >- placeholders for context chunks;
# >- a placeholder for the user query.
#
# >Set up the Q&A Assistant API. The API must contain:
# >- a `/query` endpoint, which accepts the user's question and returns the answer based on the retrieved documents.

# %% [markdown]
# `api_task2.py` is a simple FastAPI application with the required endpoint. To setup server, open a terminal and run a command `uvicorn api_task2:app --port 8001 --reload`

# %% [markdown]
# Testing endpoint requests:

# %%
user_question = "Побудова мережі Петрі"

response = requests.post("http://127.0.0.1:8001/query", json={"question": user_question})
data = response.json()

print("Question:", user_question)
print("\nAnswer:", data["answer"])
print("\nContext used by Gemini:", data["context_used"])
# Out:
# Question: Побудова мережі Петрі
#
# Answer: Для побудови мережі Петрі потрібно:
# *   Виділити події, що виникають в системі, і поставити у відповідність кожній події перехід мережі Петрі.
# *   З'ясувати умови, за яких виникає кожна подія, і поставити у відповідність кожній умові позицію мережі Петрі.
# *   Визначити кількість фішок у позиції мережі Петрі, що символізує виконання умови.
# *   З'єднати позиції та переходи відповідно до логіки виникнення подій у системі:
#     *   Якщо умова передує виконанню події, то з'єднати відповідну позицію з відповідним переходом.
#     *   Якщо умова є наслідком виконання події, то з'єднати відповідний перехід з відповідною позицією.
#
# Context used by Gemini: ['засобами мереж Петрі потрібно: • виділити події, що виникають в системі, і поставити у відповідність кожній події перехід мережі Петрі; • з’ясувати умови, при яких виникає кожна з подій, і поставити у відповідність кожній умові позицію мережі Петрі; • визначити кількість фішок у позиції мережі Петрі, що символізує виконання умови; • з’єднати позиції та Переходи відповідно до логіки виникнення подій у системі: якщо умова передує виконанню події, то з’єднати в мережі Петрі відповідну позицію з відповідним Переходом; якщо умова являється наслідком виконання події, то з’єднати в мережі Петрі', '! Будь-яку мережу масового обслуговування можна представити мережею Петрі !', '. Мережа Петрі, що представляє процес виникнення та усунення не-справностей T1 T3 P2 P3 P1 P4 T2 Рисунок 4.21. Формалізована мережа Петрі, що представляє процес виникнення та усунення несправностей 146 . Розв’яжемо систему рівнянь для відшукання вектора w, який задовольняє умові (4.41): Оскільки усі компоненти вектора w цілі додатні чиста, досліджувана мережа Петрі являється збережуваною. Зауважимо, що властивість зберігання має фізичний зміст. Наприклад, в даній мережі Петрі, сумарна кількість маркерів в позиціях за будь-якого досяжного маркірування, дорівнює 4']

# %%
user_question = "З яких етапів складається процес моделювання?"

response = requests.post("http://127.0.0.1:8001/query", json={"question": user_question})
data = response.json()

print("Question:", user_question)
print("\nAnswer:", data["answer"])
print("\nContext used by Gemini:", data["context_used"])
# Out:
# Question: З яких етапів складається процес моделювання?
#
# Answer: Процес моделювання складається з таких етапів:
#
# 1.  **Визначення мети та задачі моделювання.**
# 2.  **Вербальний опис системи**, що разом з описом змінних, структури системи, цілі та задачі дослідження складає концептуальну модель системи.
# 3.  **Вибір теоретичної бази** для побудови моделі, враховуючи концептуальну модель та інструментальні засоби.
# 4.  **Стратегічне планування експериментів**, яке включає визначення тривалості одного прогону, кількості прогонів, типу аналізу та побудову матриці планування.
#
# Context used by Gemini: ['. 1.6. Процес моделювання Процес моделювання складається з кількох етапів. На першому етапі дослідник визначає мету та задачу моделювання. На другому етапі, виходячи з мети та задачі моделювання, дослідник приступає до вербального опису системи. Опис набору змінних моделі, разом із описом структури системи та формулюванням цілі та задачі дослідження складає концептуальну модель системи. Виходячи з концептуальної моделі системи та з огляду на вибір інструментальних засобів, дослідник робить вибір теоретичної бази, на основі якої буде побудована модель системи', '. Звісно, що процес моделювання може бути представлений етапами тільки у звіті про результати моделювання. У ході моделювання досліднику доводиться неодноразово повертатись до попередніх етапів і уточнювати постановку задачі, формальний опис моделі, алгоритм реалізації або план проведення експериментів поступового наближаючись до мети. На рисунку 1.4 представлений процес моделювання з урахуванням можливих повернень до попередніх етапів моделювання. 16 1.6', '. В результаті цього етапу планування повинні бути визначені тривалість одного прогону (в одиницях модельного часу) і кількість прогонів. На третьому етапі приступають до стратегічного планування експериментів, метою якого є визначення такої серії експериментів, що забезпечить отримання бажаної інформації про відгук моделі при мінімальних витратах. В результаті цього етапу планування потрібно визначити тип аналізу, який буде використаний, та побудувати матрицю 226 планування відповідно до обраного типу аналізу та заданої кількості факторів']
